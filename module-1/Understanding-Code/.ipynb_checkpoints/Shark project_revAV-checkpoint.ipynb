# %%
import pandas as pd

# %%
import os

# %%
# os.chdir('C:\\Users\\virrginie.broly\\Documents\\4.Training\\Ironhack\\dataV2-labs\\module-1\\Pipelines-Project')

# %%
# use spyder

# %%
shark=pd.read_csv('shark.csv', encoding = 'latin1')

# %%
#shark.head()

# %%
#shark.info()

# %%
shark.shape
# Out:
# (5992, 24)

# %%
shark_na = shark.isna().sum()
shark_missing = (shark_na[shark_na>0]/shark.shape[0]*100).round(2)
shark_missing
# Out:
# Case Number                0.02
# Country                    0.72
# Area                       6.72
# Location                   8.29
# Activity                   8.79
# Name                       3.34
# Sex                        9.48
# Age                       44.75
# Injury                     0.47
# Fatal (Y/N)                0.33
# Time                      53.61
# Species                   48.97
# Investigator or Source     0.28
# pdf                        0.03
# href formula               0.05
# href                       0.08
# Case Number.1              0.03
# Case Number.2              0.03
# original order             0.03
# Unnamed: 22               99.98
# Unnamed: 23               99.97
# dtype: float64

# %% [markdown]
# Delete the columns that have more than 90% of missing values

# %%
drop_cols = shark_missing[shark_missing>90].index
drop_cols
# Out:
# Index(['Unnamed: 22', 'Unnamed: 23'], dtype='object')

# %%
shark = shark.drop(drop_cols, axis=1)
shark.head()
# Out:
#     Case Number       Date  Year        Type    Country      Area  \
# 0  2016.09.18.c  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  2016.09.18.b  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  2016.09.18.a  18-Sep-16  2016  Unprovoked        USA   Florida
# 3    2016.09.17  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4    2016.09.15  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location Activity             Name Sex   ...  \
# 0  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 1  New Smyrna Beach, Volusia County  Surfing   Chucky Luciano    M  ...
# 2  New Smyrna Beach, Volusia County  Surfing             male    M  ...
# 3                  Thirteenth Beach  Surfing  Rory Angiolella    M  ...
# 4                       Bells Beach  Surfing             male    M  ...
#
#   Fatal (Y/N)   Time   Species        Investigator or Source  \
# 0           N  13h00        NaN  Orlando Sentinel, 9/19/2016
# ...

# %% [markdown]
# # Drop the columns not needed

# %%
drop_col = ['Case Number', 'Activity', 'Age', 'Time','Species ','Investigator or Source','pdf','href formula', 'href','Case Number.1','Case Number.2', 'original order']
shark = shark.drop(drop_col, axis=1)
shark.head()
# Out:
#         Date  Year        Type    Country      Area  \
# 0  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  18-Sep-16  2016  Unprovoked        USA   Florida
# 3  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location             Name Sex   \
# 0  New Smyrna Beach, Volusia County             male    M
# 1  New Smyrna Beach, Volusia County   Chucky Luciano    M
# 2  New Smyrna Beach, Volusia County             male    M
# 3                  Thirteenth Beach  Rory Angiolella    M
# 4                       Bells Beach             male    M
#
#                                   Injury Fatal (Y/N)
# 0                  Minor injury to thigh           N
# 1                   Lacerations to hands           N
# 2               Lacerations to lower leg           N
# 3           Struck by fin on chest & leg           N
# ...

# %% [markdown]
# # Cleaning of Injuries

# %%
# Replace the NaN values by 'Not reported'
shark.Injury = shark.Injury.fillna('Not reported')

# %%
shark.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5993 entries, 0 to 5992
# Data columns (total 10 columns):
# Date           5993 non-null object
# Year           5993 non-null int64
# Type           5993 non-null object
# Country        5950 non-null object
# Area           5590 non-null object
# Location       5496 non-null object
# Name           5793 non-null object
# Sex            5425 non-null object
# Injury         5993 non-null object
# Fatal (Y/N)    5973 non-null object
# dtypes: int64(1), object(9)
# memory usage: 468.3+ KB

# %%
# Creation of a dictionnary containing all the different words in the Injury column and their frequency
injury_words = [
    x for x in ' '.join(
        shark.Injury.str.lower().tolist()
    ).split() if x.isalpha()
]
injury_set = set(injury_words)
injury_dct = {i:injury_words.count(i) for i in injury_set}

# %%
# it seams you gave up this next part, so delete from final file or comment if you realy want to keep it!!!!

# %%
# Order the dictionnary by frequency
import operator
injury_dct=dict(sorted(injury_dct.items(),key=operator.itemgetter(1),reverse=True))
injury_dct
# Out:
# {'to': 1470,
#  'bitten': 1373,
#  'shark': 1127,
#  'no': 852,
#  'fatal': 826,
#  'leg': 818,
#  'right': 808,
#  'left': 807,
#  'foot': 713,
#  'lacerations': 560,
#  'provoked': 554,
#  'incident': 549,
#  'by': 542,
#  'injury': 482,
#  'lacerated': 440,
#  'hand': 394,
#  'the': 388,
#  'of': 386,
#  'arm': 369,
#  'thigh': 368,
#  'on': 356,
#  'severed': 251,
#  'calf': 244,
#  'laceration': 232,
#  'and': 230,
#  'ankle': 218,
#  'in': 218,
#  'his': 215,
#  'minor': 208,
#  'a': 205,
#  'bit': 202,
#  'lower': 189,
#  'boat': 176,
#  'was': 169,
#  'puncture': 163,
#  'but': 160,
#  'wounds': 158,
#  'forearm': 148,
#  'not': 146,
#  'survived': 144,
#  'recovered': 139,
#  'hooked': 138,
#  'knee': 131,
#  'from': 130,
#  'sharks': 129,
#  'board': 125,
#  'he': 122,
#  'were': 118,
#  'severely': 117,
#  'injured': 116,
#  'body': 112,
#  'injuries': 101,
#  'legs': 95,
#  'surgically': 88,
#  'amputated': 87,
#  'with': 83,
#  'surfboard': 79,
#  'at': 77,
# ...

# %%
body_lst = ['arm','bumped', 'eye','eyebrow','belly','leg','breast','thumb','elbow','fist','finger','foot','feet','ankle','buttocks','hair','neck','hand','wrist','hip','chin','knee','head','lip','mouth','nose','nostril','thigh','ear','bottom','bum','back','underarm','forearm','shoulder','forehead','waist','calf','calves','cheek','eyelash','lash','tooth','teeth','toe','tongue']
clean_dct = {'leg':'leg','foot':'foot','hand':'hand','arm':'arm','thigh':'leg','calf':'leg','ankle':'foot','forearm':'arm','knee':'leg','legs':'leg','shoulder':'arm','wrist':'arm','back':'trunk','fingers':'hand','hip':'hip','finger':'hand','buttocks':'buttocks','head':'face','elbow':'arm','hands':'hand','feet':'foot','arms':'arm','toe':'foot','toes':'foot','neck':'face','thumb':'hand','thighs':'leg','teeth':'face','tooth':'face','bottom':'buttocks','nose':'face','kneecap':'leg','forearms':'arm','calves':'clave','cheek':'face','waist':'waist','ankles':'foot','mouth':'face','hips':'hip','ear':'face','forehead':'face','knees':'leg','bump':'buttocks','armpit':'arm','chine':'trunk','chin':'trunk','elbows':'arm','fist':'hand','wrists':'hand','lip':'face','breast':'trunk','thumbs':'hand','eye':'face','anklel':'foot','nostril':'face', 'chest':'trunk'}

# %%
#using redgex here would eliminate the next cleaning stage by selecting only \bear\b
for parts in body_lst:
    for i 
    re.findall(r'\b'+parts+'\w*?,)
# Out:
#   File "<ipython-input-36-87b067545a08>", line 3
#     re.finall(r'\b'+parts+'\w*?)
#                                 ^
# SyntaxError: EOL while scanning string literal

# %%
# Make a list of the injury dict keys that starts with the key of the body dict in order to extract the body parts from the innjury dict
lst = []
for i in injury_dct :
    for j in body_lst:
        if i.startswith(j):
            lst.append(i)

# %%
# From the injury dict, select only the items that are body part
injury_dct_cleaned1 = { j:injury_dct[j] for i in lst for j in injury_dct if i==j}

# %%
injury_dct_cleaned1
# Out:
# {'backed': 1,
#  'eye': 1,
#  'thigh': 368,
#  'waist': 3,
#  'foot': 713,
#  'mouthed': 2,
#  'breastplate': 2,
#  'eyewitness': 1,
#  'legs': 95,
#  'toes': 20,
#  'fist': 1,
#  'wrists': 1,
#  'elbows': 1,
#  'calves': 4,
#  'leg': 818,
#  'hand': 394,
#  'feet': 28,
#  'knees': 2,
#  'bump': 2,
#  'head': 38,
#  'breast': 1,
#  'lip': 1,
#  'chine': 1,
#  'ear': 3,
#  'toothmarks': 8,
#  'hip': 42,
#  'elbow': 36,
#  'shoulder': 75,
#  'earlier': 5,
#  'thighs': 17,
#  'nostril': 1,
#  'arms': 26,
#  'forehead': 2,
#  'knee': 131,
#  'thumb': 17,
#  'finger': 41,
#  'chin': 1,
#  'neck': 18,
#  'back': 49,
#  'heading': 1,
#  'thumbs': 1,
#  'buttocks': 40,
#  'lashed': 2,
#  'earthquake': 1,
#  'tooth': 13,
#  'armpit': 1,
#  'kneecap': 5,
#  'hips': 3,
#  'arm': 369,
#  'anklel': 1,
#  'nose': 6,
#  'fingers': 45,
#  'toe': 26,
#  'teeth': 13,
#  'hands': 35,
#  'calf': 244,
#  'forearms': 4,
#  'fingertips': 1,
#  'wrist': 58,
#  'ankles': 3,
#  'mouth': 3,
#  'ankle': 218,
# ...

# %%
# Remove from the dictionnary the remaining keys that are not body parts
remove_lst = ['earlier','teethmarks', 'mouthed', 'breastplate', 'lashed', 'eyewitness', 'backed', 'earthquake', 'fingertips','heading','bumped']
for i in remove_lst :
    del injury_dct_cleaned1[i]

# %%
injury_dct_cleaned1
# Out:
# {'leg': 818,
#  'foot': 713,
#  'hand': 394,
#  'arm': 369,
#  'thigh': 368,
#  'calf': 244,
#  'ankle': 218,
#  'forearm': 148,
#  'knee': 131,
#  'legs': 95,
#  'shoulder': 75,
#  'wrist': 58,
#  'back': 49,
#  'fingers': 45,
#  'hip': 42,
#  'finger': 41,
#  'buttocks': 40,
#  'head': 38,
#  'elbow': 36,
#  'hands': 35,
#  'feet': 28,
#  'toe': 26,
#  'arms': 26,
#  'toes': 20,
#  'neck': 18,
#  'thighs': 17,
#  'thumb': 17,
#  'teeth': 13,
#  'tooth': 13,
#  'bottom': 9,
#  'toothmarks': 8,
#  'nose': 6,
#  'kneecap': 5,
#  'forearms': 4,
#  'calves': 4,
#  'cheek': 4,
#  'waist': 3,
#  'ankles': 3,
#  'ear': 3,
#  'mouth': 3,
#  'hips': 3,
#  'bump': 2,
#  'forehead': 2,
#  'knees': 2,
#  'breast': 1,
#  'chine': 1,
#  'armpit': 1,
#  'anklel': 1,
#  'wrists': 1,
#  'thumbs': 1,
#  'lip': 1,
#  'nostril': 1,
#  'elbows': 1,
#  'chin': 1,
#  'fist': 1,
#  'eye': 1}

# %%
# Creation of a dictionary that will affect to each key of injury_dct_cleaned1 a new value for uniformization purpose
clean_dct = {'leg':'leg','foot':'foot','hand':'hand','arm':'arm','thigh':'leg','calf':'leg','ankle':'foot','forearm':'arm','knee':'leg','legs':'leg','shoulder':'arm','wrist':'arm','back':'trunk','fingers':'hand','hip':'hip','finger':'hand','buttocks':'buttocks','head':'face','elbow':'arm','hands':'hand','feet':'foot','arms':'arm','toe':'foot','toes':'foot','neck':'face','thumb':'hand','thighs':'leg','teeth':'face','tooth':'face','bottom':'buttocks','nose':'face','kneecap':'leg','forearms':'arm','calves':'clave','cheek':'face','waist':'waist','ankles':'foot','mouth':'face','hips':'hip','ear':'face','forehead':'face','knees':'leg','bump':'buttocks','armpit':'arm','chine':'trunk','chin':'trunk','elbows':'arm','fist':'hand','wrists':'hand','lip':'face','breast':'trunk','thumbs':'hand','eye':'face','anklel':'foot','nostril':'face', 'chest':'trunk'}

# %%
# Create a Body_part_injured column with the various categories of body parts defined in the clean dictionary
# Example : ff Injury contains legs, Body_part_unjured must contain leg in accordance with the clean_dct correspondance
shark['Body_part_injured'] =""

for row in shark.index:
    row_lst=[]
    for i in str(shark.iloc[row,8]).split(" ") :
        for j in clean_dct :
            if i ==j :
                row_lst.append(clean_dct[j])
        shark.iloc[row,10]=' '.join(row_lst)
        
shark.head(20)
# Out:
#          Date  Year        Type        Country                   Area  \
# 0   18-Sep-16  2016  Unprovoked            USA                Florida
# 1   18-Sep-16  2016  Unprovoked            USA                Florida
# 2   18-Sep-16  2016  Unprovoked            USA                Florida
# 3   17-Sep-16  2016  Unprovoked      AUSTRALIA               Victoria
# 4   16-Sep-16  2016  Unprovoked      AUSTRALIA               Victoria
# 5   15-Sep-16  2016        Boat      AUSTRALIA      Western Australia
# 6   11-Sep-16  2016  Unprovoked            USA                Florida
# 7   07-Sep-16  2016  Unprovoked            USA                 Hawaii
# 8   06-Sep-16  2016  Unprovoked  NEW CALEDONIA         North Province
# 9   05-Sep-16  2016  Unprovoked            USA         South Carolina
# 10  05-Sep-16  2016  Unprovoked      AUSTRALIA      Western Australia
# 11  04-Sep-16  2016  Unprovoked            USA                Florida
# ...

# %%
# Remove the duplicate words in the Body_part_injured column (ex arm arm)
shark['Body_part_injured']= shark['Body_part_injured'].str.replace(r'\b(\w+)(\s+\1)+\b', r'\1')

# %%
shark.head(20)
# Out:
#          Date  Year        Type        Country                   Area  \
# 0   18-Sep-16  2016  Unprovoked            USA                Florida
# 1   18-Sep-16  2016  Unprovoked            USA                Florida
# 2   18-Sep-16  2016  Unprovoked            USA                Florida
# 3   17-Sep-16  2016  Unprovoked      AUSTRALIA               Victoria
# 4   16-Sep-16  2016  Unprovoked      AUSTRALIA               Victoria
# 5   15-Sep-16  2016        Boat      AUSTRALIA      Western Australia
# 6   11-Sep-16  2016  Unprovoked            USA                Florida
# 7   07-Sep-16  2016  Unprovoked            USA                 Hawaii
# 8   06-Sep-16  2016  Unprovoked  NEW CALEDONIA         North Province
# 9   05-Sep-16  2016  Unprovoked            USA         South Carolina
# 10  05-Sep-16  2016  Unprovoked      AUSTRALIA      Western Australia
# 11  04-Sep-16  2016  Unprovoked            USA                Florida
# ...

# %%
# Add an arm column (boolean: if arm in Body_part_injured the 1 if not 0 )
shark['arm'] =""
for row in shark.index:
    for i in str(shark.iloc[row,10]).split(" ") :
        if i == 'arm':
            shark.iloc[row,11]= 1

# %%
# Add the same columns 10 other categories
            
shark['buttocks'] =""
for row in shark.index:
    for i in str(shark.iloc[row,10]).split(" ") :
        if i == 'buttocks':
            shark.iloc[row,12]= 1


shark['clave'] =""
for row in shark.index:
    for i in str(shark.iloc[row,10]).split(" ") :
        if i == 'clave':
            shark.iloc[row,13]= 1

            
shark['face'] =""
for row in shark.index:
    for i in str(shark.iloc[row,10]).split(" ") :
        if i == 'face':
            shark.iloc[row,14]= 1

            
shark['foot'] =""
for row in shark.index:
    for i in str(shark.iloc[row,10]).split(" ") :
        if i == 'foot':
            shark.iloc[row,15]= 1


shark['hand'] =""
for row in shark.index:
    for i in str(shark.iloc[row,10]).split(" ") :
        if i == 'hand':
            shark.iloc[row,16]= 1

            
shark['hip'] =""
for row in shark.index:
    for i in str(shark.iloc[row,10]).split(" ") :
        if i == 'hip':
            shark.iloc[row,17]= 1

            
shark['leg'] =""
for row in shark.index:
    for i in str(shark.iloc[row,10]).split(" ") :
        if i == 'leg':
            shark.iloc[row,18]= 1

            
shark['trunk'] =""
for row in shark.index:
    for i in str(shark.iloc[row,10]).split(" ") :
        if i == 'trunk':
            shark.iloc[row,19]= 1

            
shark['waist'] =""
for row in shark.index:
    for i in str(shark.iloc[row,10]).split(" ") :
        if i == 'waist':
            shark.iloc[row,20]= 1

# %%
shark.head()
# Out:
#         Date  Year        Type    Country      Area  \
# 0  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  18-Sep-16  2016  Unprovoked        USA   Florida
# 3  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location             Name Sex   \
# 0  New Smyrna Beach, Volusia County             male    M
# 1  New Smyrna Beach, Volusia County   Chucky Luciano    M
# 2  New Smyrna Beach, Volusia County             male    M
# 3                  Thirteenth Beach  Rory Angiolella    M
# 4                       Bells Beach             male    M
#
#                                   Injury Fatal (Y/N)  ... arm buttocks clave  \
# 0                  Minor injury to thigh           N  ...
# 1                   Lacerations to hands           N  ...
# 2               Lacerations to lower leg           N  ...
# ...

# %%
for i in shark.index:
    for j in ['arm', 'buttocks', 'clave','face','foot','hand','hip','leg','trunk', 'waist'] :
        if shark.loc[i,j]== '':
            shark.loc[i,j]= 0

# %%
shark.head()
# Out:
#         Date  Year        Type    Country      Area  \
# 0  18-Sep-16  2016  Unprovoked        USA   Florida
# 1  18-Sep-16  2016  Unprovoked        USA   Florida
# 2  18-Sep-16  2016  Unprovoked        USA   Florida
# 3  17-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
# 4  16-Sep-16  2016  Unprovoked  AUSTRALIA  Victoria
#
#                            Location             Name Sex   \
# 0  New Smyrna Beach, Volusia County             male    M
# 1  New Smyrna Beach, Volusia County   Chucky Luciano    M
# 2  New Smyrna Beach, Volusia County             male    M
# 3                  Thirteenth Beach  Rory Angiolella    M
# 4                       Bells Beach             male    M
#
#                                   Injury Fatal (Y/N)  ... arm  buttocks  \
# 0                  Minor injury to thigh           N  ...   0         0
# 1                   Lacerations to hands           N  ...   0         0
# 2               Lacerations to lower leg           N  ...   0         0
# ...

# %%
results = [shark.arm.sum(),shark.buttocks.sum(),shark.clave.sum(),shark.face.sum(),shark.foot.sum(),shark.hand.sum(),shark.hip.sum(),shark.leg.sum(),shark.trunk.sum(),shark.waist.sum()]
injury_results = pd.DataFrame(results, index = ['arm', 'buttocks', 'clave','face','foot','hand','hip','leg','trunk', 'waist'], columns = ['Total'])
injury_results
# Out:
#           Total
# arm         514
# buttocks     41
# clave         3
# face         85
# foot        703
# hand        392
# hip          32
# leg        1166
# trunk        82
# waist         3

# %%
# Export the results to a csv file
injury_results.to_csv('injury_result.csv', index = True)

# %% [markdown]
# # Cleaning of year

# %% [markdown]
# For the purpose of our analysis we want to focus on the attacks that took place over the last 5 years (2012-2016)

# %%
# Have a look at unique values in Year
shark.Year.unique()
# Out:
# array([2016, 2015, 2014, 2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006,
#        2005, 2004, 2003, 2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995,
#        1984, 1994, 1993, 1992, 1991, 1990, 1989, 1969, 1988, 1987, 1986,
#        1985, 1983, 1982, 1981, 1980, 1979, 1978, 1977, 1976, 1975, 1974,
#        1973, 1972, 1971, 1970, 1968, 1967, 1966, 1965, 1964, 1963, 1962,
#        1961, 1960, 1959, 1958, 1957, 1956, 1955, 1954, 1953, 1952, 1951,
#        1950, 1949, 1948, 1848, 1947, 1946, 1945, 1944, 1943, 1942, 1941,
#        1940, 1939, 1938, 1937, 1936, 1935, 1934, 1933, 1932, 1931, 1930,
#        1929, 1928, 1927, 1926, 1925, 1924, 1923, 1922, 1921, 1920, 1919,
#        1918, 1917, 1916, 1915, 1914, 1913, 1912, 1911, 1910, 1909, 1908,
#        1907, 1906, 1905, 1904, 1903, 1902, 1901, 1900, 1899, 1898, 1897,
#        1896, 1895, 1894, 1893, 1892, 1891, 1890, 1889, 1888, 1887, 1886,
#        1885, 1884, 1883, 1882, 1881, 1880, 1879, 1878, 1877, 1876, 1875,
# ...

# %%
# Count the number of rows per unique value in Year
year_count = shark.Year.value_counts()
year_count
# Out:
# 2015    139
# 2011    128
# 2014    125
# 0       124
# 2013    122
#        ...
# 1742      1
# 1758      1
# 1818      1
# 1822      1
# 1595      1
# Name: Year, Length: 232, dtype: int64

# %%
# Have a look at the 124 lines that have year = 0
year_0 = shark[shark['Year'] == 0]

# %%
# Have a look at the unique Date of the row that have year = 0
year_0.Date.unique()
# Out:
# array(['Ca. 214 B.C.', 'Ca. 336.B.C..', '493 B.C.', 'Ca. 725 B.C.',
#        '1990 or 1991', 'Before 2016', 'Before Oct-2009', 'Before 1934',
#        '2009?', 'Before 1930', '1880-1899', 'Before 1909', 'Before 2012',
#        'Before 1916', 'Between   1951-1963', 'Before 1908', 'Before 1900',
#        'Before 1876', 'Before 2011', 'Before 2009', 'Beforer 1994',
#        'Before 1963', '1896-1913', 'Before 1936', 'Before 08-Jun-1912',
#        'Before 1911', 'Before 1901', 'No date, late 1960s', 'Before 2006',
#        'Before 2003', 'Before 2004', 'Before 1962', '1950s',
#        'No date, Before 1963', '2003?', 'No date', 'Before Feb-1998',
#        'No date, Before May-1996', 'No date, Before Mar-1995',
#        'Before 1996', 'No date, Before Aug-1989',
#        'No date, Before Aug-1987', 'No date, Before 1987',
#        'No date, Before  1975', 'No date, Before 1975',
#        'No date, Before 1969', 'No date, Before 3-Jan-1967',
# ...

# %%
# They are all out of our scope except maybe the 'Before 2016' row so let's have a look at this one
shark[(shark['Year'] == 0) & (shark['Date'] == 'Before 2016')]
# Out:
#              Date  Year        Type Country     Area   Location  \
# 5873  Before 2016     0  Unprovoked   KENYA  Mombasa  Kilindini
#
#                Name Sex  Injury Fatal (Y/N)  ... arm buttocks clave face foot  \
# 5873  Hamisi Njenga    M  FATAL           Y  ...
#
#      hand hip leg trunk waist
# 5873
#
# [1 rows x 21 columns]

# %% [markdown]
# After investigating on the internet we did not found any additional information so we will keep the row as it is

# %% [markdown]
# # Cleaning of country

# %% [markdown]
# Country is needed in order to determine where we will open a new office. But for this purpose we will focus on the last 5 years so we will narrow the scope of our investigation to 2012-2016

# %%
shark.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5992 entries, 0 to 5991
# Data columns (total 21 columns):
# Date                 5992 non-null object
# Year                 5992 non-null int64
# Type                 5992 non-null object
# Country              5949 non-null object
# Area                 5590 non-null object
# Location             5496 non-null object
# Name                 5792 non-null object
# Sex                  5425 non-null object
# Injury               5992 non-null object
# Fatal (Y/N)          5973 non-null object
# Body_part_injured    5992 non-null object
# arm                  5992 non-null object
# buttocks             5992 non-null object
# clave                5992 non-null object
# face                 5992 non-null object
# foot                 5992 non-null object
# hand                 5992 non-null object
# hip                  5992 non-null object
# leg                  5992 non-null object
# trunk                5992 non-null object
# ...

# %%
# Creation of a dataframe that focus only on the 2012-2016 period
shark_5Y = shark[shark['Year'] >= 2012]
shark_5Y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 606 entries, 0 to 605
# Data columns (total 21 columns):
# Date                 606 non-null object
# Year                 606 non-null int64
# Type                 606 non-null object
# Country              605 non-null object
# Area                 572 non-null object
# Location             571 non-null object
# Name                 603 non-null object
# Sex                  584 non-null object
# Injury               606 non-null object
# Fatal (Y/N)          605 non-null object
# Body_part_injured    606 non-null object
# arm                  606 non-null object
# buttocks             606 non-null object
# clave                606 non-null object
# face                 606 non-null object
# foot                 606 non-null object
# hand                 606 non-null object
# hip                  606 non-null object
# leg                  606 non-null object
# trunk                606 non-null object
# ...

# %%
# Let's have a look at the different countries
shark_5Y.Country.value_counts()
# Out:
# USA                        313
# AUSTRALIA                  128
# SOUTH AFRICA                30
# BAHAMAS                     19
# REUNION                     12
# FRENCH POLYNESIA            10
# SPAIN                        9
# NEW ZEALAND                  8
# NEW CALEDONIA                8
# BRAZIL                       7
# MEXICO                       5
# JAPAN                        4
# JAMAICA                      3
# MOZAMBIQUE                   3
# FIJI                         2
# EGYPT                        2
# TAIWAN                       2
# ITALY                        2
# ECUADOR                      2
# TRINIDAD & TOBAGO            2
# FRANCE                       2
# CAYMAN ISLANDS               2
# ARUBA                        1
# MAURITIUS                    1
# CROATIA                      1
# SEYCHELLES                   1
# DIEGO GARCIA                 1
# ATLANTIC OCEAN               1
# INDONESIA                    1
# TONGA                        1
# ...

# %%
# The only problem is Fiji and FIJI so we will upper all the column to avoid the issue
shark.Country = shark.Country.str.upper()

# %%
shark[shark['Year'] >= 2012].Country.value_counts()
# Out:
# USA                        313
# AUSTRALIA                  128
# SOUTH AFRICA                30
# BAHAMAS                     19
# REUNION                     12
# FRENCH POLYNESIA            10
# SPAIN                        9
# NEW CALEDONIA                8
# NEW ZEALAND                  8
# BRAZIL                       7
# MEXICO                       5
# JAPAN                        4
# FIJI                         3
# JAMAICA                      3
# MOZAMBIQUE                   3
# TAIWAN                       2
# TRINIDAD & TOBAGO            2
# CAYMAN ISLANDS               2
# EGYPT                        2
# FRANCE                       2
# ITALY                        2
# ECUADOR                      2
# CANADA                       1
# KIRIBATI                     1
# INDONESIA                    1
# CROATIA                      1
# BELIZE                       1
# ARUBA                        1
# DIEGO GARCIA                 1
# TONGA                        1
# ...

# %%
# Now let's have a look at the NaN countries for our period scope
shark[(shark['Year'] >= 2012) & (shark['Country'].isna())]
# Out:
#        Date  Year     Type Country Area Location            Name Sex   \
# 303  Aug-14  2014  Invalid     NaN  NaN      NaN  Cuban refugees    M
#
#                                              Injury Fatal (Y/N)  ... arm  \
# 303  Shark involvement prior to death not confirmed           Y  ...
#
#     buttocks clave face foot hand hip leg trunk waist
# 303
#
# [1 rows x 21 columns]

# %%
# After investigating, we have learned that the incident happened between Cuba and FLorida so we will assign it to the USA
shark.iloc[303,'Country'] = 'USA'

# %%
shark[(shark['Year'] >= 2012) & (shark['Country'].isna())]
# Out:
# Empty DataFrame
# Columns: [Date, Year, Type, Country, Area, Location, Name, Sex , Injury, Fatal (Y/N), Body_part_injured, arm, buttocks, clave, face, foot, hand, hip, leg, trunk, waist]
# Index: []
#
# [0 rows x 21 columns]

# %%
# Create a dictionary with the count of accident per country over the last 5 years
unique_countries = shark[shark['Year'] >= 2012].Country.unique()
year_list = [2012, 2013,2014,2015,2016]
year_dct = {j:[shark[(shark['Year'] == i) & (shark['Country']==j)].Country.count() for i in year_list] for j in unique_countries}
year_dct
# Out:
# {'USA': [64, 60, 66, 72, 52],
#  'AUSTRALIA': [26, 20, 29, 30, 23],
#  'NEW CALEDONIA': [0, 1, 1, 1, 5],
#  'REUNION': [3, 3, 1, 4, 1],
#  'BAHAMAS': [2, 7, 3, 3, 4],
#  'SPAIN': [0, 1, 4, 2, 2],
#  'CHINA': [0, 0, 0, 0, 1],
#  'JAPAN': [0, 0, 3, 0, 1],
#  'COLUMBIA': [0, 0, 0, 0, 1],
#  'SOUTH AFRICA': [5, 8, 5, 9, 3],
#  'EGYPT': [0, 0, 0, 1, 1],
#  'NEW ZEALAND': [2, 2, 3, 0, 1],
#  'INDONESIA': [0, 0, 0, 0, 1],
#  'FRENCH POLYNESIA': [1, 2, 2, 4, 1],
#  'CAPE VERDE': [0, 0, 0, 0, 1],
#  'FIJI': [1, 0, 0, 1, 1],
#  'BRAZIL': [1, 2, 1, 2, 1],
#  'DOMINICAN REPUBLIC': [0, 0, 0, 0, 1],
#  'CAYMAN ISLANDS': [0, 0, 1, 0, 1],
#  'UNITED ARAB EMIRATES': [0, 0, 0, 0, 1],
#  'ARUBA': [0, 0, 0, 1, 0],
#  'MOZAMBIQUE': [0, 0, 0, 3, 0],
#  'THAILAND': [0, 0, 0, 1, 0],
#  'PUERTO RICO': [0, 0, 0, 1, 0],
#  'ITALY': [1, 0, 0, 1, 0],
#  'MEXICO': [2, 2, 0, 1, 0],
#  'ATLANTIC OCEAN': [0, 0, 0, 1, 0],
#  'GREECE': [0, 0, 1, 0, 0],
#  'MAURITIUS': [0, 0, 1, 0, 0],
# ...

# %%
# Create a dataframe with the dictionary created
country_result_df= pd.DataFrame(year_dct).transpose()
country_result_df.columns = year_list

# %%
# Export the results to a csv file
country_result_df.to_csv('country_result.csv', index = True)
